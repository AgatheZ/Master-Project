# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
acc_std = np.array([0.01, 0.033, 0.014, 0.031, 0.002, 0.003, 0.002, 0.002])
acc = np.array([0.682, 0.7, 0.706, 0.719, 0.735, 0.783, 0.816, 0.843])
auroc = np.array([0.722, 0.763, 0.771, 0.790, 0.785, 0.779, 0.747, 0.753])
auroc_std = np.array([0.033, 0.045, 0.025, 0.034, 0.023, 0.018, 0.037, 0.024])
f1 = np.array([0.809, 0.693, 0.616, 0.418, 0.050, 0,0,0])
f1_std = np.array([0.01, 0.032, 0.017, 0.053, 0.069, 0,0,0])

# %%
fig, ax = plt.subplots()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# plt.plot(range(3,11), acc, marker = '.', label = 'Accuracy')
# plt.fill_between(range(3,11), acc-acc_std, acc+acc_std, alpha = 0.2)
# # plt.plot(range(3,11), f1)
# plt.plot(range(3,11), auroc, marker = '.', label = 'AUROC')
# plt.fill_between(range(3,11), auroc-auroc_std, auroc+auroc_std, alpha = 0.2)
plt.plot(range(3,11), f1, marker = '.', label = 'F1-Score', color='green')
plt.fill_between(range(3,11), f1-f1_std, f1+f1_std, alpha = 0.2, color = 'green')
plt.legend()
plt.xlabel('LOS threshold value (days)')
plt.ylabel('Value')
# Out:
# Text(0, 0.5, 'Value')
